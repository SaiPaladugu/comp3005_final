# %%
# imports, auth, and connection

import os
import json
import psycopg2
import pandas as pd
import uuid

conn_params = {
    'dbname': 'project_database',
    'user': 'postgres',
    'password': '1234',
    'host': 'localhost'
}

conn = psycopg2.connect(**conn_params)

# %%
# competitions

# filtering relevant comps
def filter_competitions(data):
    criteria = [
        {"competition_name": "La Liga", "season_name": "2020/2021"},
        {"competition_name": "La Liga", "season_name": "2019/2020"},
        {"competition_name": "La Liga", "season_name": "2018/2019"},
        {"competition_name": "Premier League", "season_name": "2003/2004"},
    ]
    filtered_data = [item for item in data if any(c["competition_name"] == item["competition_name"] and c["season_name"] == item["season_name"] for c in criteria)]
    return filtered_data

with open('open-data/data/competitions.json', 'r') as file:
    competitions_data = json.load(file)

competitions_to_insert = filter_competitions(competitions_data)

cur = conn.cursor()

insert_query = '''
    INSERT INTO Competitions (
        competition_id,
        season_id,
        country_name,
        competition_name,
        competition_gender,
        competition_youth,
        competition_international,
        season_name
    ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
    ON CONFLICT (competition_id, season_id) DO NOTHING;
'''

for item in competitions_to_insert:
    cur.execute(insert_query, (
        item["competition_id"],
        item["season_id"],
        item["country_name"],
        item["competition_name"],
        item["competition_gender"],
        item["competition_youth"],
        item["competition_international"],
        item["season_name"]
    ))

conn.commit()
cur.close()

# %%
# verifying competitions

query = """
SELECT * FROM Competitions;
"""

df_competitions = pd.read_sql_query(query, conn)
df_competitions
# Out:
# /var/folders/1b/q25_hkjn4ss017jjnfh0ytnw0000gn/T/ipykernel_94197/935086658.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_competitions = pd.read_sql_query(query, conn)
#    competition_id  season_id country_name competition_name competition_gender  \
# 0              11         90        Spain          La Liga               male
# 1              11         42        Spain          La Liga               male
# 2              11          4        Spain          La Liga               male
# 3               2         44      England   Premier League               male
#
#    competition_youth  competition_international season_name
# 0              False                      False   2020/2021
# 1              False                      False   2019/2020
# 2              False                      False   2018/2019
# 3              False                      False   2003/2004

# %%
# matches data

cur = conn.cursor()

seasons_dirs = {
    "11": ["90", "42", "4"],  # La Liga: Season IDs for 2020/2021, 2019/2020, 2018/2019
    "2": ["44"]  # Premier League: Season ID for 2003/2004
}

base_path = 'open-data/data/matches'

insert_sql = '''
INSERT INTO Matches (
    match_id, match_date, kick_off, country, competition, competition_id, season_id, 
    home_team, home_team_gender, home_team_manager_id, home_team_manager_name, home_team_group, home_team_country, 
    away_team, away_team_gender, away_team_manager_id, away_team_manager_name, away_team_group, away_team_country, 
    home_score, away_score, match_status, match_week, competition_stage, 
    stadium, stadium_country, referee_name, referee_country
) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
ON CONFLICT (match_id) DO NOTHING;
'''

def get_country_name(country_data):
    return country_data.get('name', 'na') if isinstance(country_data, dict) else 'na'

for comp_id, seasons in seasons_dirs.items():
    for season_id in seasons:
        file_path = os.path.join(base_path, comp_id, f"{season_id}.json")
        with open(file_path, 'r') as file:
            matches_data = json.load(file)
            for match in matches_data:
                try:
                    parameters = (
                        match.get("match_id"),
                        match.get("match_date"),
                        match.get("kick_off"),
                        match["competition"].get("country_name"),
                        match["competition"].get("competition_name"),
                        match["competition"].get("competition_id"),
                        match["season"].get("season_id"),
                        match["home_team"].get("home_team_name"),
                        match["home_team"].get("home_team_gender"),
                        match["home_team"].get("managers", [{}])[0].get("id", None),
                        match["home_team"].get("managers", [{}])[0].get("name", None),
                        match["home_team"].get("home_team_group"),
                        get_country_name(match["home_team"].get("country")),
                        match["away_team"].get("away_team_name"),
                        match["away_team"].get("away_team_gender"),
                        match["away_team"].get("managers", [{}])[0].get("id", None),
                        match["away_team"].get("managers", [{}])[0].get("name", None),
                        match["away_team"].get("away_team_group"),
                        get_country_name(match["away_team"].get("country")),
                        match.get("home_score"),
                        match.get("away_score"),
                        match.get("match_status"),
                        match.get("match_week"),
                        match["competition_stage"].get("name"),
                        match.get("stadium", {}).get("name"),
                        match.get("stadium", {}).get("country", {}).get("name"),
                        match.get("referee", {}).get("name", None),
                        match.get("referee", {}).get("country", {}).get("name", None)
                    )

                    cur.execute(insert_sql, parameters)
                except psycopg2.Error as e:
                    print(f"An error occurred: {e}")
                    conn.rollback()
                    continue 
                
            conn.commit()

conn.commit()
cur.close()

# %%
# matches verification

query = """
SELECT * FROM Matches;
"""

df_matches = pd.read_sql_query(query, conn)
df_matches
# Out:
# /var/folders/1b/q25_hkjn4ss017jjnfh0ytnw0000gn/T/ipykernel_2318/998478867.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_matches = pd.read_sql_query(query, conn)
#      match_id  match_date  kick_off  country     competition  competition_id  \
# 0     3749310  2003-12-29  21:00:00  England  Premier League               2
# 1     3749493  2003-08-16  16:00:00  England  Premier League               2
# 2     3749434  2003-11-22  16:00:00  England  Premier League               2
# 3     3749192  2003-11-30  15:00:00  England  Premier League               2
# 4     3749196  2003-11-08  16:00:00  England  Premier League               2
# ..        ...         ...       ...      ...             ...             ...
# 135   3749552  2003-09-21  17:05:00  England  Premier League               2
# 136   3749296  2003-09-13  16:00:00  England  Premier League               2
# 137   3749454  2003-08-31  17:05:00  England  Premier League               2
# 138   3749276  2004-02-21  13:30:00  England  Premier League               2
# 139   3749068  2004-04-25  17:05:00  England  Premier League               2
#
#      season_id          home_team home_team_gender  home_team_manager_id  ...  \
# 0           44        Southampton             male                3722.0  ...
# 1           44            Arsenal             male                 577.0  ...
# 2           44    Birmingham City             male                  37.0  ...
# 3           44            Arsenal             male                 577.0  ...
# 4           44            Arsenal             male                 577.0  ...
# ..         ...                ...              ...                   ...  ...
# 135         44  Manchester United             male                 790.0  ...
# 136         44            Arsenal             male                 577.0  ...
# 137         44    Manchester City             male                4202.0  ...
# 138         44            Chelsea             male                  60.0  ...
# 139         44  Tottenham Hotspur             male                3533.0  ...
#
#     away_team_country home_score away_score match_status match_week  \
# 0             England          0          1    available          1
# 1             England          2          1    available          1
# 2             England          0          3    available          1
# 3             England          0          0    available         14
# 4             England          2          1    available         12
# ..                ...        ...        ...          ...        ...
# 135           England          0          0    available          1
# 136           England          1          1    available          5
# 137           England          1          2    available          1
# 138           England          1          2    available          2
# 139           England          2          2    available          2
#
#      competition_stage              stadium stadium_country referee_name  \
# 0       Regular Season  St. Mary''s Stadium         England         None
# 1       Regular Season     Highbury Stadium         England         None
# 2       Regular Season  St. Andrews Stadium         England         None
# 3       Regular Season     Highbury Stadium         England         None
# 4       Regular Season     Highbury Stadium         England         None
# ..                 ...                  ...             ...          ...
# 135     Regular Season         Old Trafford         England         None
# 136     Regular Season     Highbury Stadium         England         None
# 137     Regular Season       Etihad Stadium         England         None
# 138     Regular Season      Stamford Bridge         England         None
# 139     Regular Season      White Hart Lane         England         None
#
#      referee_country
# 0               None
# 1               None
# 2               None
# 3               None
# 4               None
# ..               ...
# 135             None
# 136             None
# 137             None
# 138             None
# 139             None
#
# [140 rows x 28 columns]

# %%
# get relevant matches as only events/lineups from these games will matter
cur = conn.cursor()

# SQL query to select match_id from matches
sql_query = "SELECT match_id FROM matches;"
cur.execute(sql_query)

# Fetch all the results
results = cur.fetchall()

match_ids = set()

# iterate over the results and add each match_id to the set
for result in results:
    match_ids.add(result[0])

print(match_ids)
print(len(match_ids))

cur.close()
# Out:
# {3773457, 303634, 3773466, 3749403, 3773474, 303652, 3773477, 303664, 303666, 3749431, 3773497, 303674, 3749434, 303680, 303682, 3749448, 15946, 3749453, 3749454, 303696, 3773523, 303700, 15956, 3773526, 3749462, 3749465, 303707, 303715, 15973, 15978, 3773547, 303725, 3773552, 15986, 303731, 3749493, 3773565, 15998, 3773571, 16010, 3773585, 3773586, 3773587, 3749522, 3749526, 16023, 3749528, 3773593, 3773597, 16029, 3749552, 16056, 3773625, 3749052, 3773631, 16073, 3749068, 16079, 3749590, 16086, 3773656, 3764440, 3749079, 3773660, 3773661, 16095, 3773665, 3749603, 3773672, 16109, 3749108, 16120, 3773689, 3749117, 3773695, 3749631, 16131, 16136, 3749642, 3749133, 303377, 16149, 16157, 3749153, 303400, 16173, 16182, 303421, 16190, 16196, 303430, 3749192, 3749196, 16205, 16215, 303451, 16231, 303470, 16240, 303473, 3749233, 303479, 16248, 3749246, 303487, 303493, 3749253, 16265, 3749257, 303504, 16275, 3749274, 303516, 303517, 3749278, 3749276, 16289, 303524, 303532, 3749296, 16306, 3764661, 3773369, 3773372, 303548, 3749310, 16317, 3773377, 3773386, 3773387, 3773403, 3749346, 3773415, 303596, 3749358, 3749360, 303600, 3773428, 303610, 303615}
# 140

# %%
# handling relevant files only to keep size of repo manageable

base_path = 'open-data/data'
events_path = os.path.join(base_path, 'events')
lineups_path = os.path.join(base_path, 'lineups')

def clean_directory(directory_path):
    for filename in os.listdir(directory_path):
        match_id = filename.split('.')[0]
        
        if match_id.isdigit():
            match_id = int(match_id)
            
            if match_id not in match_ids:
                file_path = os.path.join(directory_path, filename)
                print(f"Deleting: {file_path}")
                os.remove(file_path)
        else:
            print(f"Skipping non-match file: {filename}")

# clean events directory
clean_directory(events_path)

# clean lineups directory
clean_directory(lineups_path)

print("Cleanup completed.")
# Out:
# Deleting: open-data/data/events/3879600.json
# Deleting: open-data/data/events/3901250.json
# Deleting: open-data/data/events/3754300.json
# Deleting: open-data/data/events/2275050.json
# Deleting: open-data/data/events/19795.json
# Deleting: open-data/data/events/3825894.json
# Deleting: open-data/data/events/7298.json
# Deleting: open-data/data/events/3753996.json
# Deleting: open-data/data/events/3900504.json
# Deleting: open-data/data/events/3753979.json
# Deleting: open-data/data/events/265958.json
# Deleting: open-data/data/events/3890360.json
# Deleting: open-data/data/events/3879745.json
# Deleting: open-data/data/events/3754245.json
# Deleting: open-data/data/events/69182.json
# Deleting: open-data/data/events/3902240.json
# Deleting: open-data/data/events/3890419.json
# Deleting: open-data/data/events/18242.json
# Deleting: open-data/data/events/69301.json
# Deleting: open-data/data/events/3901196.json
# Deleting: open-data/data/events/3775631.json
# Deleting: open-data/data/events/3825601.json
# Deleting: open-data/data/events/3754183.json
# Deleting: open-data/data/events/69244.json
# Deleting: open-data/data/events/3825744.json
# Deleting: open-data/data/events/3901179.json
# Deleting: open-data/data/events/3754029.json
# Deleting: open-data/data/events/3788742.json
# Deleting: open-data/data/events/3890272.json
# Deleting: open-data/data/events/3829419.json
# Deleting: open-data/data/events/3825590.json
# Deleting: open-data/data/events/3837954.json
# Deleting: open-data/data/events/3901207.json
# Deleting: open-data/data/events/3879657.json
# Deleting: open-data/data/events/3879712.json
# Deleting: open-data/data/events/3754212.json
# Deleting: open-data/data/events/2275142.json
# Deleting: open-data/data/events/3878553.json
# Deleting: open-data/data/events/3890337.json
# Deleting: open-data/data/events/266620.json
# Deleting: open-data/data/events/3900553.json
# Deleting: open-data/data/events/3893798.json
# Deleting: open-data/data/events/3825656.json
# Deleting: open-data/data/events/3879591.json
# Deleting: open-data/data/events/3754091.json
# Deleting: open-data/data/events/7559.json
# Deleting: open-data/data/events/3813271.json
# Deleting: open-data/data/events/3825713.json
# Deleting: open-data/data/events/3920389.json
# Deleting: open-data/data/events/69213.json
# Deleting: open-data/data/events/3754341.json
# Deleting: open-data/data/events/3901211.json
# Deleting: open-data/data/events/3879641.json
# Deleting: open-data/data/events/3825586.json
# Deleting: open-data/data/events/3890264.json
# Deleting: open-data/data/events/3900545.json
# Deleting: open-data/data/events/3890321.json
# Deleting: open-data/data/events/3878545.json
# Deleting: open-data/data/events/3869354.json
# Deleting: open-data/data/events/3825569.json
# Deleting: open-data/data/events/3920409.json
# Deleting: open-data/data/events/3775559.json
# Deleting: open-data/data/events/2275154.json
# Deleting: open-data/data/events/3754204.json
# Deleting: open-data/data/events/3879704.json
# Deleting: open-data/data/events/3888711.json
# Deleting: open-data/data/events/3813288.json
# Deleting: open-data/data/events/3890458.json
# Deleting: open-data/data/events/69340.json
# Deleting: open-data/data/events/3754087.json
# Deleting: open-data/data/events/3879587.json
# Deleting: open-data/data/events/3825640.json
# Deleting: open-data/data/events/69205.json
# Deleting: open-data/data/events/3754068.json
# Deleting: open-data/data/events/3879568.json
# Deleting: open-data/data/events/3922658.json
# Deleting: open-data/data/events/3825705.json
# Deleting: open-data/data/events/19804.json
# Deleting: open-data/data/events/8655.json
# Deleting: open-data/data/events/3813267.json
# Deleting: open-data/data/events/266724.json
# Deleting: open-data/data/events/3753980.json
# Deleting: open-data/data/events/3817859.json
# Deleting: open-data/data/events/3829458.json
# Deleting: open-data/data/events/3825882.json
# Deleting: open-data/data/events/3890399.json
# Deleting: open-data/data/events/19783.json
# Deleting: open-data/data/events/3754316.json
# Deleting: open-data/data/events/3879616.json
# Deleting: open-data/data/events/3901246.json
# Deleting: open-data/data/events/22980.json
# Deleting: open-data/data/events/2275103.json
# Deleting: open-data/data/events/3754253.json
# Deleting: open-data/data/events/3879753.json
# Deleting: open-data/data/events/3890376.json
# Deleting: open-data/data/events/3893809.json
# Deleting: open-data/data/events/3900512.json
# Deleting: open-data/data/events/3825617.json
# Deleting: open-data/data/events/3775627.json
# Deleting: open-data/data/events/3802837.json
# Deleting: open-data/data/events/3901180.json
# Deleting: open-data/data/events/9855.json
# Deleting: open-data/data/events/3788754.json
# Deleting: open-data/data/events/3825752.json
# Deleting: open-data/data/events/69252.json
# Deleting: open-data/data/events/3754195.json
# Deleting: open-data/data/events/70264.json
# Deleting: open-data/data/events/3879682.json
# Deleting: open-data/data/events/19717.json
# Deleting: open-data/data/events/3754228.json
# Deleting: open-data/data/events/3879728.json
# Deleting: open-data/data/events/3775575.json
# Deleting: open-data/data/events/3825816.json
# Deleting: open-data/data/events/3900569.json
# Deleting: open-data/data/events/3900586.json
# Deleting: open-data/data/events/68341.json
# Deleting: open-data/data/events/3829423.json
# Deleting: open-data/data/events/3890531.json
# Deleting: open-data/data/events/3879817.json
# Deleting: open-data/data/events/3825729.json
# Deleting: open-data/data/events/3754044.json
# Deleting: open-data/data/events/9592.json
# Deleting: open-data/data/events/3879544.json
# Deleting: open-data/data/events/69229.json
# Deleting: open-data/data/events/3825683.json
# Deleting: open-data/data/events/3754101.json
# Deleting: open-data/data/events/3890474.json
# Deleting: open-data/data/events/7563.json
# Deleting: open-data/data/events/3893825.json
# Deleting: open-data/data/events/3825841.json
# Deleting: open-data/data/events/3900494.json
# Deleting: open-data/data/events/19740.json
# Deleting: open-data/data/events/22943.json
# Deleting: open-data/data/events/2275085.json
# Deleting: open-data/data/events/3857292.json
# Deleting: open-data/data/events/3754290.json
# Deleting: open-data/data/events/3879790.json
# Deleting: open-data/data/events/69157.json
# Deleting: open-data/data/events/3829474.json
# Deleting: open-data/data/events/68316.json
# Deleting: open-data/data/events/3817875.json
# Deleting: open-data/data/events/3825904.json
# Deleting: open-data/data/events/267660.json
# Deleting: open-data/data/events/3754013.json
# Deleting: open-data/data/events/7471.json
# Deleting: open-data/data/events/3879840.json
# Deleting: open-data/data/events/7534.json
# Deleting: open-data/data/events/3890423.json
# Deleting: open-data/data/events/3900617.json
# Deleting: open-data/data/events/3825791.json
# Deleting: open-data/data/events/3754156.json
# Deleting: open-data/data/events/69291.json
# Deleting: open-data/data/events/70225.json
# Deleting: open-data/data/events/2275093.json
# Deleting: open-data/data/events/22955.json
# Deleting: open-data/data/events/19756.json
# Deleting: open-data/data/events/2275139.json
# Deleting: open-data/data/events/3879769.json
# Deleting: open-data/data/events/3754269.json
# Deleting: open-data/data/events/3825857.json
# Deleting: open-data/data/events/3893833.json
# Deleting: open-data/data/events/3900528.json
# Deleting: open-data/data/events/3817863.json
# Deleting: open-data/data/events/3889182.json
# Deleting: open-data/data/events/3829462.json
# Deleting: open-data/data/events/69141.json
# Deleting: open-data/data/events/3879786.json
# Deleting: open-data/data/events/3754286.json
# Deleting: open-data/data/events/3857284.json
# Deleting: open-data/data/events/3837885.json
# Deleting: open-data/data/events/3879856.json
# Deleting: open-data/data/events/9880.json
# Deleting: open-data/data/events/3835338.json
# Deleting: open-data/data/events/3901155.json
# Deleting: open-data/data/events/3754005.json
# Deleting: open-data/data/events/3825768.json
# Deleting: open-data/data/events/69268.json
# Deleting: open-data/data/events/3802948.json
# Deleting: open-data/data/events/69287.json
# Deleting: open-data/data/events/3754140.json
# Deleting: open-data/data/events/3825787.json
# Deleting: open-data/data/events/3900601.json
# Deleting: open-data/data/events/3890435.json
# Deleting: open-data/data/events/3878601.json
# Deleting: open-data/data/events/7522.json
# Deleting: open-data/data/events/3825800.json
# Deleting: open-data/data/events/3775563.json
# Deleting: open-data/data/events/3879694.json
# Deleting: open-data/data/events/9642.json
# Deleting: open-data/data/events/70272.json
# Deleting: open-data/data/events/3764237.json
# Deleting: open-data/data/events/3829435.json
# Deleting: open-data/data/events/68357.json
# Deleting: open-data/data/events/3900590.json
# Deleting: open-data/data/events/265866.json
# Deleting: open-data/data/events/3844386.json
# Deleting: open-data/data/events/3825695.json
# Deleting: open-data/data/events/3879552.json
# Deleting: open-data/data/events/3754052.json
# Deleting: open-data/data/events/3879801.json
# Deleting: open-data/data/events/7430.json
# Deleting: open-data/data/events/3869552.json
# Deleting: open-data/data/events/3890527.json
# Deleting: open-data/data/events/266525.json
# Deleting: open-data/data/events/3813318.json
# Deleting: open-data/data/events/3890462.json
# Deleting: open-data/data/events/3754117.json
# Deleting: open-data/data/events/3754160.json
# Deleting: open-data/data/events/267343.json
# Deleting: open-data/data/events/3900621.json
# Deleting: open-data/data/events/3890415.json
# Deleting: open-data/data/events/3890550.json
# Deleting: open-data/data/events/3879876.json
# Deleting: open-data/data/events/3901175.json
# Deleting: open-data/data/events/3754025.json
# Deleting: open-data/data/events/3825748.json
# Deleting: open-data/data/events/69248.json
# Deleting: open-data/data/events/68320.json
# Deleting: open-data/data/events/3829442.json
# Deleting: open-data/data/events/3890383.json
# Deleting: open-data/data/events/3825898.json
# Deleting: open-data/data/events/19799.json
# Deleting: open-data/data/events/69161.json
# Deleting: open-data/data/events/3764240.json
# Deleting: open-data/data/events/267085.json
# Deleting: open-data/data/events/267590.json
# Deleting: open-data/data/events/19776.json
# Deleting: open-data/data/events/3879749.json
# Deleting: open-data/data/events/3754249.json
# Deleting: open-data/data/events/3825877.json
# Deleting: open-data/data/events/3829507.json
# Deleting: open-data/data/events/3753975.json
# Deleting: open-data/data/events/3893813.json
# Deleting: open-data/data/events/3900508.json
# Deleting: open-data/data/events/7555.json
# Deleting: open-data/data/events/3813292.json
# Deleting: open-data/data/events/3890442.json
# Deleting: open-data/data/events/3754137.json
# Deleting: open-data/data/events/3893794.json
# Deleting: open-data/data/events/3920385.json
# Deleting: open-data/data/events/3879572.json
# Deleting: open-data/data/events/3754072.json
# Deleting: open-data/data/events/3879821.json
# Deleting: open-data/data/events/266440.json
# Deleting: open-data/data/events/3794690.json
# Deleting: open-data/data/events/3890507.json
# Deleting: open-data/data/events/3829415.json
# Deleting: open-data/data/events/3922838.json
# Deleting: open-data/data/events/3890291.json
# Deleting: open-data/data/events/3825820.json
# Deleting: open-data/data/events/3775543.json
# Deleting: open-data/data/events/3920413.json
# Deleting: open-data/data/events/3825573.json
# Deleting: open-data/data/events/267197.json
# Deleting: open-data/data/events/3754121.json
# Deleting: open-data/data/events/3890454.json
# Deleting: open-data/data/events/3813284.json
# Deleting: open-data/data/events/7543.json
# Deleting: open-data/data/events/3890511.json
# Deleting: open-data/data/events/3794686.json
# Deleting: open-data/data/events/3879837.json
# Deleting: open-data/data/events/19808.json
# Deleting: open-data/data/events/3825709.json
# Deleting: open-data/data/events/3754064.json
# Deleting: open-data/data/events/3879564.json
# Deleting: open-data/data/events/3920393.json
# Deleting: open-data/data/events/69209.json
# Deleting: open-data/data/events/3890268.json
# Deleting: open-data/data/events/68361.json
# Deleting: open-data/data/events/70301.json
# Deleting: open-data/data/events/22934.json
# Deleting: open-data/data/events/19737.json
# Deleting: open-data/data/events/3754208.json
# Deleting: open-data/data/events/3879708.json
# Deleting: open-data/data/events/3920405.json
# Deleting: open-data/data/events/3825565.json
# Deleting: open-data/data/events/3775555.json
# Deleting: open-data/data/events/3878549.json
# Deleting: open-data/data/events/3825836.json
# Deleting: open-data/data/events/3890287.json
# Deleting: open-data/data/events/3900549.json
# Deleting: open-data/data/events/3890403.json
# Deleting: open-data/data/events/3900637.json
# Deleting: open-data/data/events/3754176.json
# Deleting: open-data/data/events/3754199.json
# Deleting: open-data/data/events/266952.json
# Deleting: open-data/data/events/3754033.json
# Deleting: open-data/data/events/3901163.json
# Deleting: open-data/data/events/3788758.json
# Deleting: open-data/data/events/7451.json
# Deleting: open-data/data/events/3879860.json
# Deleting: open-data/data/events/3890546.json
# Deleting: open-data/data/events/267569.json
# Deleting: open-data/data/events/69177.json
# Deleting: open-data/data/events/3890395.json
# Deleting: open-data/data/events/3829454.json
# Deleting: open-data/data/events/68336.json
# Deleting: open-data/data/events/3817855.json
# Deleting: open-data/data/events/3893805.json
# Deleting: open-data/data/events/3829511.json
# Deleting: open-data/data/events/3825861.json
# Deleting: open-data/data/events/19760.json
# Deleting: open-data/data/events/22963.json
# Deleting: open-data/data/events/266883.json
# Deleting: open-data/data/events/69225.json
# Deleting: open-data/data/events/3754048.json
# Deleting: open-data/data/events/3879548.json
# Deleting: open-data/data/events/3825725.json
# Deleting: open-data/data/events/266929.json
# Deleting: open-data/data/events/3890497.json
# Deleting: open-data/data/events/3869118.json
# Deleting: open-data/data/events/7580.json
# Deleting: open-data/data/events/3890478.json
# Deleting: open-data/data/events/3813302.json
# Deleting: open-data/data/events/3825660.json
# Deleting: open-data/data/events/3775650.json
# Deleting: open-data/data/events/3900565.json
# Deleting: open-data/data/events/3890301.json
# Deleting: open-data/data/events/3775579.json
# Deleting: open-data/data/events/3754224.json
# Deleting: open-data/data/events/3879724.json
# Deleting: open-data/data/events/3837827.json
# Deleting: open-data/data/events/70287.json
# Deleting: open-data/data/events/3901231.json
# Deleting: open-data/data/events/3879661.json
# Deleting: open-data/data/events/3775596.json
# Deleting: open-data/data/events/3788774.json
# Deleting: open-data/data/events/3835322.json
# Deleting: open-data/data/events/3825772.json
# Deleting: open-data/data/events/69272.json
# Deleting: open-data/data/events/3825637.json
# Deleting: open-data/data/events/3775607.json
# Deleting: open-data/data/events/69337.json
# Deleting: open-data/data/events/7492.json
# Deleting: open-data/data/events/7538.json
# Deleting: open-data/data/events/3857271.json
# Deleting: open-data/data/events/2275089.json
# Deleting: open-data/data/events/267400.json
# Deleting: open-data/data/events/3754273.json
# Deleting: open-data/data/events/3879773.json
# Deleting: open-data/data/events/3900498.json
# Deleting: open-data/data/events/3890356.json
# Deleting: open-data/data/events/3829497.json
# Deleting: open-data/data/events/3817896.json
# Deleting: open-data/data/events/3893829.json
# Deleting: open-data/data/events/3900532.json
# Deleting: open-data/data/events/3825908.json
# Deleting: open-data/data/events/3817879.json
# Deleting: open-data/data/events/3829478.json
# Deleting: open-data/data/events/3754336.json
# Deleting: open-data/data/events/3879636.json
# Deleting: open-data/data/events/3923881.json
# Deleting: open-data/data/events/69264.json
# Deleting: open-data/data/events/3825764.json
# Deleting: open-data/data/events/3901159.json
# Deleting: open-data/data/events/3754009.json
# Deleting: open-data/data/events/3835334.json
# Deleting: open-data/data/events/3788762.json
# Deleting: open-data/data/events/3890439.json
# Deleting: open-data/data/events/7484.json
# Deleting: open-data/data/events/69321.json
# Deleting: open-data/data/events/3906389.json
# Deleting: open-data/data/events/3775611.json
# Deleting: open-data/data/events/3825621.json
# Deleting: open-data/data/events/3900524.json
# Deleting: open-data/data/events/3817880.json
# Deleting: open-data/data/events/3829481.json
# Deleting: open-data/data/events/3890340.json
# Deleting: open-data/data/events/3879765.json
# Deleting: open-data/data/events/3754265.json
# Deleting: open-data/data/events/3857267.json
# Deleting: open-data/data/events/3857288.json
# Deleting: open-data/data/events/3879620.json
# Deleting: open-data/data/events/3754320.json
# Deleting: open-data/data/events/2275070.json
# Deleting: open-data/data/events/3890481.json
# Deleting: open-data/data/events/3825733.json
# Deleting: open-data/data/events/3795107.json
# Deleting: open-data/data/events/69233.json
# Deleting: open-data/data/events/3825699.json
# Deleting: open-data/data/events/3775646.json
# Deleting: open-data/data/events/3825676.json
# Deleting: open-data/data/events/18235.json
# Deleting: open-data/data/events/3813314.json
# Deleting: open-data/data/events/7579.json
# Deleting: open-data/data/events/3879698.json
# Deleting: open-data/data/events/3879732.json
# Deleting: open-data/data/events/3754232.json
# Deleting: open-data/data/events/3890317.json
# Deleting: open-data/data/events/3900573.json
# Deleting: open-data/data/events/3829439.json
# Deleting: open-data/data/events/3775580.json
# Deleting: open-data/data/events/3901227.json
# Deleting: open-data/data/events/3879677.json
# Deleting: open-data/data/events/70291.json
# Deleting: open-data/data/events/2275027.json
# Deleting: open-data/data/events/3879699.json
# Deleting: open-data/data/events/3901733.json
# Deleting: open-data/data/events/3879733.json
# Deleting: open-data/data/events/3754233.json
# Deleting: open-data/data/events/3890316.json
# Deleting: open-data/data/events/3900572.json
# Deleting: open-data/data/events/3829438.json
# Deleting: open-data/data/events/3775581.json
# Deleting: open-data/data/events/2275026.json
# Deleting: open-data/data/events/3901226.json
# Deleting: open-data/data/events/3879676.json
# Deleting: open-data/data/events/3890480.json
# Deleting: open-data/data/events/3825732.json
# Deleting: open-data/data/events/69232.json
# Deleting: open-data/data/events/3825698.json
# Deleting: open-data/data/events/3775647.json
# Deleting: open-data/data/events/3825677.json
# Deleting: open-data/data/events/3813315.json
# Deleting: open-data/data/events/7578.json
# Deleting: open-data/data/events/266528.json
# Deleting: open-data/data/events/3817881.json
# Deleting: open-data/data/events/3900525.json
# Deleting: open-data/data/events/3890341.json
# Deleting: open-data/data/events/3829480.json
# Deleting: open-data/data/events/3879764.json
# Deleting: open-data/data/events/3754264.json
# Deleting: open-data/data/events/3857266.json
# Deleting: open-data/data/events/3857289.json
# Deleting: open-data/data/events/3879621.json
# Deleting: open-data/data/events/3754321.json
# Deleting: open-data/data/events/3923880.json
# Deleting: open-data/data/events/69265.json
# Deleting: open-data/data/events/3901158.json
# Deleting: open-data/data/events/3754008.json
# Deleting: open-data/data/events/3825765.json
# Deleting: open-data/data/events/3835335.json
# Deleting: open-data/data/events/3788763.json
# Deleting: open-data/data/events/3890438.json
# Deleting: open-data/data/events/7485.json
# Deleting: open-data/data/events/69320.json
# Deleting: open-data/data/events/266986.json
# Deleting: open-data/data/events/3775610.json
# Deleting: open-data/data/events/3825620.json
# Deleting: open-data/data/events/2275088.json
# Deleting: open-data/data/events/3857270.json
# Deleting: open-data/data/events/3754272.json
# Deleting: open-data/data/events/3879772.json
# Deleting: open-data/data/events/2275122.json
# Deleting: open-data/data/events/3900499.json
# Deleting: open-data/data/events/3829496.json
# Deleting: open-data/data/events/3890357.json
# Deleting: open-data/data/events/3900533.json
# Deleting: open-data/data/events/3817897.json
# Deleting: open-data/data/events/3893828.json
# Deleting: open-data/data/events/3802683.json
# Deleting: open-data/data/events/3817878.json
# Deleting: open-data/data/events/3829479.json
# Deleting: open-data/data/events/3754337.json
# Deleting: open-data/data/events/3879637.json
# Deleting: open-data/data/events/3788775.json
# Deleting: open-data/data/events/3835323.json
# Deleting: open-data/data/events/3825773.json
# Deleting: open-data/data/events/69273.json
# Deleting: open-data/data/events/3825636.json
# Deleting: open-data/data/events/3775606.json
# Deleting: open-data/data/events/69336.json
# Deleting: open-data/data/events/7493.json
# Deleting: open-data/data/events/3838004.json
# Deleting: open-data/data/events/7539.json
# Deleting: open-data/data/events/3900564.json
# Deleting: open-data/data/events/3890300.json
# Deleting: open-data/data/events/3754225.json
# Deleting: open-data/data/events/3879725.json
# Deleting: open-data/data/events/3775578.json
# Deleting: open-data/data/events/70286.json
# Deleting: open-data/data/events/3901230.json
# Deleting: open-data/data/events/3879660.json
# Deleting: open-data/data/events/2275030.json
# Deleting: open-data/data/events/3775597.json
# Deleting: open-data/data/events/3837963.json
# Deleting: open-data/data/events/3802904.json
# Deleting: open-data/data/events/69224.json
# Deleting: open-data/data/events/3825724.json
# Deleting: open-data/data/events/3754049.json
# Deleting: open-data/data/events/3879549.json
# Deleting: open-data/data/events/3890496.json
# Deleting: open-data/data/events/7581.json
# Deleting: open-data/data/events/3890479.json
# Deleting: open-data/data/events/3813303.json
# Deleting: open-data/data/events/3825661.json
# Deleting: open-data/data/events/3775651.json
# Deleting: open-data/data/events/3837918.json
# Deleting: open-data/data/events/267138.json
# Deleting: open-data/data/events/69176.json
# Deleting: open-data/data/events/3829455.json
# Deleting: open-data/data/events/3890394.json
# Deleting: open-data/data/events/68337.json
# Deleting: open-data/data/events/3817854.json
# Deleting: open-data/data/events/3893804.json
# Deleting: open-data/data/events/3829510.json
# Deleting: open-data/data/events/3825860.json
# Deleting: open-data/data/events/69199.json
# Deleting: open-data/data/events/19761.json
# Deleting: open-data/data/events/22962.json
# Deleting: open-data/data/events/3900636.json
# Deleting: open-data/data/events/3890402.json
# Deleting: open-data/data/events/3754177.json
# Deleting: open-data/data/events/3754198.json
# Deleting: open-data/data/events/3754032.json
# Deleting: open-data/data/events/3901162.json
# Deleting: open-data/data/events/3879861.json
# Deleting: open-data/data/events/3788759.json
# Deleting: open-data/data/events/3890547.json
# Deleting: open-data/data/events/3890269.json
# Deleting: open-data/data/events/68360.json
# Deleting: open-data/data/events/3802752.json
# Deleting: open-data/data/events/70300.json
# Deleting: open-data/data/events/19736.json
# Deleting: open-data/data/events/3920404.json
# Deleting: open-data/data/events/3825564.json
# Deleting: open-data/data/events/3775554.json
# Deleting: open-data/data/events/3754209.json
# Deleting: open-data/data/events/3879709.json
# Deleting: open-data/data/events/3825837.json
# Deleting: open-data/data/events/3878548.json
# Deleting: open-data/data/events/3890286.json
# Deleting: open-data/data/events/3900548.json
# Deleting: open-data/data/events/3754120.json
# Deleting: open-data/data/events/3869420.json
# Deleting: open-data/data/events/3890455.json
# Deleting: open-data/data/events/266142.json
# Deleting: open-data/data/events/3813285.json
# Deleting: open-data/data/events/7542.json
# Deleting: open-data/data/events/3890510.json
# Deleting: open-data/data/events/3794687.json
# Deleting: open-data/data/events/8658.json
# Deleting: open-data/data/events/3879836.json
# Deleting: open-data/data/events/19809.json
# Deleting: open-data/data/events/3754065.json
# Deleting: open-data/data/events/3879565.json
# Deleting: open-data/data/events/3825708.json
# Deleting: open-data/data/events/3920392.json
# Deleting: open-data/data/events/69208.json
# Deleting: open-data/data/events/9726.json
# Deleting: open-data/data/events/69137.json
# Deleting: open-data/data/events/3829414.json
# Deleting: open-data/data/events/3890290.json
# Deleting: open-data/data/events/3825821.json
# Deleting: open-data/data/events/3775542.json
# Deleting: open-data/data/events/3920412.json
# Deleting: open-data/data/events/3825572.json
# Deleting: open-data/data/events/19720.json
# Deleting: open-data/data/events/7554.json
# Deleting: open-data/data/events/3813293.json
# Deleting: open-data/data/events/3890443.json
# Deleting: open-data/data/events/3922356.json
# Deleting: open-data/data/events/3754136.json
# Deleting: open-data/data/events/3893795.json
# Deleting: open-data/data/events/3920384.json
# Deleting: open-data/data/events/3879573.json
# Deleting: open-data/data/events/3754073.json
# Deleting: open-data/data/events/3879820.json
# Deleting: open-data/data/events/3794691.json
# Deleting: open-data/data/events/3890506.json
# Deleting: open-data/data/events/68321.json
# Deleting: open-data/data/events/3890382.json
# Deleting: open-data/data/events/3825899.json
# Deleting: open-data/data/events/3829443.json
# Deleting: open-data/data/events/69160.json
# Deleting: open-data/data/events/19798.json
# Deleting: open-data/data/events/3764241.json
# Deleting: open-data/data/events/22974.json
# Deleting: open-data/data/events/19777.json
# Deleting: open-data/data/events/3879748.json
# Deleting: open-data/data/events/3754248.json
# Deleting: open-data/data/events/3825876.json
# Deleting: open-data/data/events/3753974.json
# Deleting: open-data/data/events/3829506.json
# Deleting: open-data/data/events/3900509.json
# Deleting: open-data/data/events/3893812.json
# Deleting: open-data/data/events/3754161.json
# Deleting: open-data/data/events/3890414.json
# Deleting: open-data/data/events/3900620.json
# Deleting: open-data/data/events/3890551.json
# Deleting: open-data/data/events/3835319.json
# Deleting: open-data/data/events/3825749.json
# Deleting: open-data/data/events/3901174.json
# Deleting: open-data/data/events/3754024.json
# Deleting: open-data/data/events/3922244.json
# Deleting: open-data/data/events/69249.json
# Deleting: open-data/data/events/3844387.json
# Deleting: open-data/data/events/3825694.json
# Deleting: open-data/data/events/3879553.json
# Deleting: open-data/data/events/3754053.json
# Deleting: open-data/data/events/3879800.json
# Deleting: open-data/data/events/3890526.json
# Deleting: open-data/data/events/3890463.json
# Deleting: open-data/data/events/3754116.json
# Deleting: open-data/data/events/3825801.json
# Deleting: open-data/data/events/3775562.json
# Deleting: open-data/data/events/3879695.json
# Deleting: open-data/data/events/70273.json
# Deleting: open-data/data/events/3764236.json
# Deleting: open-data/data/events/3829434.json
# Deleting: open-data/data/events/68356.json
# Deleting: open-data/data/events/3900591.json
# Deleting: open-data/data/events/266066.json
# Deleting: open-data/data/events/3879857.json
# Deleting: open-data/data/events/3835339.json
# Deleting: open-data/data/events/3825769.json
# Deleting: open-data/data/events/3901154.json
# Deleting: open-data/data/events/3754004.json
# Deleting: open-data/data/events/69269.json
# Deleting: open-data/data/events/69286.json
# Deleting: open-data/data/events/3754141.json
# Deleting: open-data/data/events/3825786.json
# Deleting: open-data/data/events/3922321.json
# Deleting: open-data/data/events/3890434.json
# Deleting: open-data/data/events/3900600.json
# Deleting: open-data/data/events/7523.json
# Deleting: open-data/data/events/3878600.json
# Deleting: open-data/data/events/2275092.json
# Deleting: open-data/data/events/70224.json
# Deleting: open-data/data/events/19757.json
# Deleting: open-data/data/events/3879768.json
# Deleting: open-data/data/events/3754268.json
# Deleting: open-data/data/events/2275138.json
# Deleting: open-data/data/events/3825856.json
# Deleting: open-data/data/events/3802676.json
# Deleting: open-data/data/events/3900529.json
# Deleting: open-data/data/events/3893832.json
# Deleting: open-data/data/events/3802699.json
# Deleting: open-data/data/events/265830.json
# Deleting: open-data/data/events/3817862.json
# Deleting: open-data/data/events/3829463.json
# Deleting: open-data/data/events/3879787.json
# Deleting: open-data/data/events/3754287.json
# Deleting: open-data/data/events/3857285.json
# Deleting: open-data/data/events/3754012.json
# Deleting: open-data/data/events/3879841.json
# Deleting: open-data/data/events/266420.json
# Deleting: open-data/data/events/3888854.json
# Deleting: open-data/data/events/7535.json
# Deleting: open-data/data/events/3900616.json
# Deleting: open-data/data/events/3890422.json
# Deleting: open-data/data/events/3825790.json
# Deleting: open-data/data/events/3754157.json
# Deleting: open-data/data/events/3893824.json
# Deleting: open-data/data/events/3825840.json
# Deleting: open-data/data/events/265963.json
# Deleting: open-data/data/events/3900495.json
# Deleting: open-data/data/events/19741.json
# Deleting: open-data/data/events/22942.json
# Deleting: open-data/data/events/9602.json
# Deleting: open-data/data/events/2275084.json
# Deleting: open-data/data/events/3857293.json
# Deleting: open-data/data/events/3754291.json
# Deleting: open-data/data/events/3837938.json
# Deleting: open-data/data/events/3879791.json
# Deleting: open-data/data/events/69156.json
# Deleting: open-data/data/events/3829475.json
# Deleting: open-data/data/events/68317.json
# Deleting: open-data/data/events/3817874.json
# Deleting: open-data/data/events/3825905.json
# Deleting: open-data/data/events/3890530.json
# Deleting: open-data/data/events/3879816.json
# Deleting: open-data/data/events/266477.json
# Deleting: open-data/data/events/3754045.json
# Deleting: open-data/data/events/3879545.json
# Deleting: open-data/data/events/3825728.json
# Deleting: open-data/data/events/69228.json
# Deleting: open-data/data/events/3825682.json
# Deleting: open-data/data/events/3754100.json
# Deleting: open-data/data/events/266498.json
# Deleting: open-data/data/events/3837650.json
# Deleting: open-data/data/events/3890475.json
# Deleting: open-data/data/events/7562.json
# Deleting: open-data/data/events/3879683.json
# Deleting: open-data/data/events/19716.json
# Deleting: open-data/data/events/3775574.json
# Deleting: open-data/data/events/3754229.json
# Deleting: open-data/data/events/3879729.json
# Deleting: open-data/data/events/3825817.json
# Deleting: open-data/data/events/3900568.json
# Deleting: open-data/data/events/3900587.json
# Deleting: open-data/data/events/68340.json
# Deleting: open-data/data/events/3829422.json
# Deleting: open-data/data/events/3825616.json
# Deleting: open-data/data/events/3775626.json
# Deleting: open-data/data/events/3901181.json
# Deleting: open-data/data/events/69316.json
# Deleting: open-data/data/events/7519.json
# Deleting: open-data/data/events/3788755.json
# Deleting: open-data/data/events/3877170.json
# Deleting: open-data/data/events/3825753.json
# Deleting: open-data/data/events/69253.json
# Deleting: open-data/data/events/3754194.json
# Deleting: open-data/data/events/3753981.json
# Deleting: open-data/data/events/3817858.json
# Deleting: open-data/data/events/3825883.json
# Deleting: open-data/data/events/3890398.json
# Deleting: open-data/data/events/3829459.json
# Deleting: open-data/data/events/3802709.json
# Deleting: open-data/data/events/19782.json
# Deleting: open-data/data/events/3754317.json
# Deleting: open-data/data/events/3879617.json
# Deleting: open-data/data/events/3901247.json
# Deleting: open-data/data/events/22981.json
# Deleting: open-data/data/events/69195.json
# Deleting: open-data/data/events/3754252.json
# Deleting: open-data/data/events/3879752.json
# Deleting: open-data/data/events/2275102.json
# Deleting: open-data/data/events/3890377.json
# Deleting: open-data/data/events/3900513.json
# Deleting: open-data/data/events/3893808.json
# Deleting: open-data/data/events/266230.json
# Deleting: open-data/data/events/3813289.json
# Deleting: open-data/data/events/3890459.json
# Deleting: open-data/data/events/3754086.json
# Deleting: open-data/data/events/3879586.json
# Deleting: open-data/data/events/3825641.json
# Deleting: open-data/data/events/3825704.json
# Deleting: open-data/data/events/3922659.json
# Deleting: open-data/data/events/3754069.json
# Deleting: open-data/data/events/3879569.json
# Deleting: open-data/data/events/19805.json
# Deleting: open-data/data/events/3813266.json
# Deleting: open-data/data/events/3750180.json
# Deleting: open-data/data/events/3754340.json
# Deleting: open-data/data/events/3901210.json
# Deleting: open-data/data/events/3879640.json
# Deleting: open-data/data/events/267533.json
# Deleting: open-data/data/events/3825587.json
# Deleting: open-data/data/events/267499.json
# Deleting: open-data/data/events/3890265.json
# Deleting: open-data/data/events/3900544.json
# Deleting: open-data/data/events/3878544.json
# Deleting: open-data/data/events/265918.json
# Deleting: open-data/data/events/3890320.json
# Deleting: open-data/data/events/3754205.json
# Deleting: open-data/data/events/3879705.json
# Deleting: open-data/data/events/3825568.json
# Deleting: open-data/data/events/3920408.json
# Deleting: open-data/data/events/3775558.json
# Deleting: open-data/data/events/22939.json
# Deleting: open-data/data/events/3893799.json
# Deleting: open-data/data/events/3825657.json
# Deleting: open-data/data/events/3879590.json
# Deleting: open-data/data/events/3754090.json
# Deleting: open-data/data/events/7558.json
# Deleting: open-data/data/events/3813270.json
# Deleting: open-data/data/events/19813.json
# Deleting: open-data/data/events/3835342.json
# Deleting: open-data/data/events/3825712.json
# Deleting: open-data/data/events/3920388.json
# Deleting: open-data/data/events/69212.json
# Deleting: open-data/data/events/3890273.json
# Deleting: open-data/data/events/3829418.json
# Deleting: open-data/data/events/3825591.json
# Deleting: open-data/data/events/3901206.json
# Deleting: open-data/data/events/3879656.json
# Deleting: open-data/data/events/3888706.json
# Deleting: open-data/data/events/3879713.json
# Deleting: open-data/data/events/3754213.json
# Deleting: open-data/data/events/3890336.json
# Deleting: open-data/data/events/3878552.json
# Deleting: open-data/data/events/3900552.json
# Deleting: open-data/data/events/3890418.json
# Deleting: open-data/data/events/18243.json
# Deleting: open-data/data/events/69300.json
# Deleting: open-data/data/events/3901197.json
# Deleting: open-data/data/events/3775630.json
# Deleting: open-data/data/events/3825600.json
# Deleting: open-data/data/events/3754182.json
# Deleting: open-data/data/events/69245.json
# Deleting: open-data/data/events/3901178.json
# Deleting: open-data/data/events/3754028.json
# Deleting: open-data/data/events/3825745.json
# Deleting: open-data/data/events/3788743.json
# Deleting: open-data/data/events/2275051.json
# Deleting: open-data/data/events/3879601.json
# Deleting: open-data/data/events/3901251.json
# Deleting: open-data/data/events/3754301.json
# Deleting: open-data/data/events/3837902.json
# Deleting: open-data/data/events/19794.json
# Deleting: open-data/data/events/3825895.json
# Deleting: open-data/data/events/3753997.json
# Deleting: open-data/data/events/3900505.json
# Deleting: open-data/data/events/3753978.json
# Deleting: open-data/data/events/3890361.json
# Deleting: open-data/data/events/3879744.json
# Deleting: open-data/data/events/3754244.json
# Deleting: open-data/data/events/69183.json
# Deleting: open-data/data/events/3900627.json
# Deleting: open-data/data/events/3890413.json
# Deleting: open-data/data/events/3754166.json
# Deleting: open-data/data/events/3901173.json
# Deleting: open-data/data/events/3754023.json
# Deleting: open-data/data/events/3754189.json
# Deleting: open-data/data/events/3922243.json
# Deleting: open-data/data/events/3890556.json
# Deleting: open-data/data/events/3879870.json
# Deleting: open-data/data/events/3788748.json
# Deleting: open-data/data/events/3829444.json
# Deleting: open-data/data/events/3890385.json
# Deleting: open-data/data/events/68326.json
# Deleting: open-data/data/events/265952.json
# Deleting: open-data/data/events/3825871.json
# Deleting: open-data/data/events/3817900.json
# Deleting: open-data/data/events/3893815.json
# Deleting: open-data/data/events/3829501.json
# Deleting: open-data/data/events/3753973.json
# Deleting: open-data/data/events/22973.json
# Deleting: open-data/data/events/267596.json
# Deleting: open-data/data/events/9799.json
# Deleting: open-data/data/events/69188.json
# Deleting: open-data/data/events/19770.json
# Deleting: open-data/data/events/3893792.json
# Deleting: open-data/data/events/3754131.json
# Deleting: open-data/data/events/3813294.json
# Deleting: open-data/data/events/7553.json
# Deleting: open-data/data/events/3890444.json
# Deleting: open-data/data/events/3879827.json
# Deleting: open-data/data/events/19818.json
# Deleting: open-data/data/events/3890501.json
# Deleting: open-data/data/events/3877090.json
# Deleting: open-data/data/events/8649.json
# Deleting: open-data/data/events/69219.json
# Deleting: open-data/data/events/3879574.json
# Deleting: open-data/data/events/3754074.json
# Deleting: open-data/data/events/3825719.json
# Deleting: open-data/data/events/3829413.json
# Deleting: open-data/data/events/3890278.json
# Deleting: open-data/data/events/19727.json
# Deleting: open-data/data/events/3775545.json
# Deleting: open-data/data/events/3825575.json
# Deleting: open-data/data/events/3920415.json
# Deleting: open-data/data/events/3879718.json
# Deleting: open-data/data/events/3754218.json
# Deleting: open-data/data/events/22924.json
# Deleting: open-data/data/events/3890297.json
# Deleting: open-data/data/events/3900559.json
# Deleting: open-data/data/events/3825826.json
# Deleting: open-data/data/events/3878559.json
# Deleting: open-data/data/events/3890452.json
# Deleting: open-data/data/events/7545.json
# Deleting: open-data/data/events/3813282.json
# Deleting: open-data/data/events/266846.json
# Deleting: open-data/data/events/3754127.json
# Deleting: open-data/data/events/3920395.json
# Deleting: open-data/data/events/267611.json
# Deleting: open-data/data/events/3754062.json
# Deleting: open-data/data/events/3879562.json
# Deleting: open-data/data/events/3890517.json
# Deleting: open-data/data/events/3879831.json
# Deleting: open-data/data/events/267492.json
# Deleting: open-data/data/events/70307.json
# Deleting: open-data/data/events/3825830.json
# Deleting: open-data/data/events/3890281.json
# Deleting: open-data/data/events/3825563.json
# Deleting: open-data/data/events/3920403.json
# Deleting: open-data/data/events/3775553.json
# Deleting: open-data/data/events/19731.json
# Deleting: open-data/data/events/3754170.json
# Deleting: open-data/data/events/3890405.json
# Deleting: open-data/data/events/3877194.json
# Deleting: open-data/data/events/3900631.json
# Deleting: open-data/data/events/7457.json
# Deleting: open-data/data/events/3879866.json
# Deleting: open-data/data/events/3890540.json
# Deleting: open-data/data/events/3827335.json
# Deleting: open-data/data/events/69258.json
# Deleting: open-data/data/events/3825758.json
# Deleting: open-data/data/events/3754035.json
# Deleting: open-data/data/events/3901165.json
# Deleting: open-data/data/events/68330.json
# Deleting: open-data/data/events/3825888.json
# Deleting: open-data/data/events/3890393.json
# Deleting: open-data/data/events/3829452.json
# Deleting: open-data/data/events/3817853.json
# Deleting: open-data/data/events/69171.json
# Deleting: open-data/data/events/19789.json
# Deleting: open-data/data/events/19766.json
# Deleting: open-data/data/events/3754259.json
# Deleting: open-data/data/events/3879759.json
# Deleting: open-data/data/events/2275109.json
# Deleting: open-data/data/events/3829517.json
# Deleting: open-data/data/events/3900518.json
# Deleting: open-data/data/events/3893803.json
# Deleting: open-data/data/events/3825867.json
# Deleting: open-data/data/events/265944.json
# Deleting: open-data/data/events/3890491.json
# Deleting: open-data/data/events/19822.json
# Deleting: open-data/data/events/7586.json
# Deleting: open-data/data/events/69223.json
# Deleting: open-data/data/events/3825689.json
# Deleting: open-data/data/events/266885.json
# Deleting: open-data/data/events/3825723.json
# Deleting: open-data/data/events/3825666.json
# Deleting: open-data/data/events/7569.json
# Deleting: open-data/data/events/3813304.json
# Deleting: open-data/data/events/3754222.json
# Deleting: open-data/data/events/3879722.json
# Deleting: open-data/data/events/3879688.json
# Deleting: open-data/data/events/266240.json
# Deleting: open-data/data/events/3900563.json
# Deleting: open-data/data/events/3890307.json
# Deleting: open-data/data/events/3829429.json
# Deleting: open-data/data/events/2275037.json
# Deleting: open-data/data/events/70281.json
# Deleting: open-data/data/events/3879667.json
# Deleting: open-data/data/events/3901237.json
# Deleting: open-data/data/events/3775590.json
# Deleting: open-data/data/events/3754019.json
# Deleting: open-data/data/events/3901149.json
# Deleting: open-data/data/events/3825774.json
# Deleting: open-data/data/events/69274.json
# Deleting: open-data/data/events/3869519.json
# Deleting: open-data/data/events/3835324.json
# Deleting: open-data/data/events/3788772.json
# Deleting: open-data/data/events/3890429.json
# Deleting: open-data/data/events/7494.json
# Deleting: open-data/data/events/3825631.json
# Deleting: open-data/data/events/3775601.json
# Deleting: open-data/data/events/69331.json
# Deleting: open-data/data/events/3890350.json
# Deleting: open-data/data/events/3829491.json
# Deleting: open-data/data/events/3817890.json
# Deleting: open-data/data/events/3900534.json
# Deleting: open-data/data/events/22949.json
# Deleting: open-data/data/events/3857277.json
# Deleting: open-data/data/events/9609.json
# Deleting: open-data/data/events/3837876.json
# Deleting: open-data/data/events/3754275.json
# Deleting: open-data/data/events/3879775.json
# Deleting: open-data/data/events/3754330.json
# Deleting: open-data/data/events/3857298.json
# Deleting: open-data/data/events/3901260.json
# Deleting: open-data/data/events/3879630.json
# Deleting: open-data/data/events/3788764.json
# Deleting: open-data/data/events/3835332.json
# Deleting: open-data/data/events/69262.json
# Deleting: open-data/data/events/3795506.json
# Deleting: open-data/data/events/3825762.json
# Deleting: open-data/data/events/69327.json
# Deleting: open-data/data/events/3775617.json
# Deleting: open-data/data/events/3825627.json
# Deleting: open-data/data/events/7482.json
# Deleting: open-data/data/events/3879763.json
# Deleting: open-data/data/lineups/3829461.json
# Deleting: open-data/data/lineups/3825854.json
# Deleting: open-data/data/lineups/3893830.json
# Deleting: open-data/data/lineups/3857268.json
# Deleting: open-data/data/lineups/2275090.json
# Deleting: open-data/data/lineups/22956.json
# Deleting: open-data/data/lineups/19755.json
# Deleting: open-data/data/lineups/3900602.json
# Deleting: open-data/data/lineups/3890436.json
# Deleting: open-data/data/lineups/3878602.json
# Deleting: open-data/data/lineups/7521.json
# Deleting: open-data/data/lineups/69284.json
# Deleting: open-data/data/lineups/3754143.json
# Deleting: open-data/data/lineups/3825784.json
# Deleting: open-data/data/lineups/3754006.json
# Deleting: open-data/data/lineups/3901156.json
# Deleting: open-data/data/lineups/266967.json
# Deleting: open-data/data/lineups/267675.json
# Deleting: open-data/data/lineups/3879855.json
# Deleting: open-data/data/lineups/3878593.json
# Deleting: open-data/data/lineups/3829436.json
# Deleting: open-data/data/lineups/68354.json
# Deleting: open-data/data/lineups/3900593.json
# Deleting: open-data/data/lineups/3764234.json
# Deleting: open-data/data/lineups/2275028.json
# Deleting: open-data/data/lineups/3879678.json
# Deleting: open-data/data/lineups/3901228.json
# Deleting: open-data/data/lineups/3795221.json
# Deleting: open-data/data/lineups/3775560.json
# Deleting: open-data/data/lineups/70271.json
# Deleting: open-data/data/lineups/3879697.json
# Deleting: open-data/data/lineups/3825803.json
# Deleting: open-data/data/lineups/3890318.json
# Deleting: open-data/data/lineups/3754114.json
# Deleting: open-data/data/lineups/3825679.json
# Deleting: open-data/data/lineups/3775649.json
# Deleting: open-data/data/lineups/7576.json
# Deleting: open-data/data/lineups/3890461.json
# Deleting: open-data/data/lineups/3879802.json
# Deleting: open-data/data/lineups/3890524.json
# Deleting: open-data/data/lineups/266033.json
# Deleting: open-data/data/lineups/3825696.json
# Deleting: open-data/data/lineups/3844385.json
# Deleting: open-data/data/lineups/3795108.json
# Deleting: open-data/data/lineups/3754051.json
# Deleting: open-data/data/lineups/3879551.json
# Cleanup completed.

# %%
# verifying that the new file count matches with the length of match_ids

base_path = 'open-data/data'
events_path = os.path.join(base_path, 'events')
lineups_path = os.path.join(base_path, 'lineups')

def count_files(directory_path):
    return len([name for name in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, name))])

events_count = count_files(events_path)
lineups_count = count_files(lineups_path)

# print the counts
print(f"Number of files in 'events': {events_count}")
print(f"Number of files in 'lineups': {lineups_count}")
# Out:
# Number of files in 'events': 140
# Number of files in 'lineups': 140

# %%
# events unique properties and their value depths within event payloads

events_dict = {
    "Event": {
        "event_id": "id",
        "match_id": "file_name",
        "event_index":"index",
        "game_period":"period",
        "start_time": "timestamp",
        "min": "minute",
        "sec": "second",
        "possession": "possession",
        "possession_team_name": ("possession_team", "name"),
        "play_pattern_name": ("play_pattern", "name"),
        "team_name": ("team", "name"),
        "player_name": ("player", "name"),
        "player_position": ("position", "name"),
        "location_x": ("location", 0),
        "location_y": ("location", 1),
        "under_pressure": "under_pressure",
        "out_of_bounds": "out",
        "duration": "duration",
    },
    "Pass": {
        "recipient_name": ("recipient", "name"),
        "pass_length": "length",
        "pass_angle": "angle",
        "pass_height": ("height", "name"),
        "end_location_x": ("end_location", 0),
        "end_location_y": ("end_location", 1),
        "deflected": "deflected",
        "is_backheel": "backheel",
        "is_cross": "cross",
        "is_cutback": "cut-back",
        "is_switch": "switch",
        "shot_assist": "shot-assist",
        "goal_assist": "goal-assist",
        "pass_body_part": ("body_part", "name"),
        "pass_type": ("type", "name"),
        "outcome_name": ("outcome", "name"),
        "technique": ("technique", "name"),
    },
    "Shot": {
        "end_location_x": ("end_location", 0),
        "end_location_y": ("end_location", 1),
        "end_location_z": ("end_location", 2),
        "aerial_won": "aerial_won",
        "follows_dribble": "follows_dribble",
        "first_time": "first_time",
        "open_goal": "open_goal",
        "statsbomb_xg": "statsbomb_xg",
        "deflected": "deflected",
        "technique_name": ("technique", "name"),
        "body_part_name": ("body_part", "name"),
        "type_name": ("type", "name"),
        "outcome_name": ("outcome", "name"),
    },
    "Dribble": {
        "overrun": "overrun",
        "nutmeg": "nutmeg",
        "no_touch": "no_touch",
        "outcome": ("outcome", "name"),
    },
    "Dribbled_Past": {
        "counterpress": "counterpress",
    },
    "Bad_Behaviour": {
        "card_colour": ("card", "name"),
    },
    "Ball_Receipt": {
        "outcome": ("outcome", "name"),
    },
    "Ball_Recovery": {
        "offensive": "offensive",
        "recovery_failure": "recovery_failure",
    },
    "Block": {
        "deflection": "deflection",
        "offensive": "offensive",
        "save_block": "save_block",
        "counterpress": "counterpress",
    },
    "Carry": {
        "end_location_x": ("end_location", 0),
        "end_location_y": ("end_location", 1),
    },
    "Clearance": {
        "aerial_won": "aerial_won",
        "body_part_name": ("body_part", "name"),
    },
    "Duel": {
        "counterpress": "counterpress",
        "duel_type": ("type", "name"),
        "outcome": ("outcome", "name"),
    },
    "Foul_Committed": {
        "counterpress": "counterpress",
        "offensive": "offensive",
        "foul_type": ("type", "name"),
        "advantage": "advantage",
        "penalty": "penalty",
        "card_colour": ("card", "name"),
    },
    "Foul_Won": {
        "defensive": "defensive",
        "advantage": "advantage",
        "penalty": "penalty",
    },
    "Goalkeeper": {
        "position": ("position", "name"),
        "technique": ("technique", "name"),
        "body_part_name": ("body_part", "name"),
        "goalkeeper_event_type": ("type", "name"),
        "outcome": ("outcome", "name"),
    },
    "Half_End": {
        "early_video_end": "early_video_end",
        "match_suspended": "match_suspended",
    },
    "Half_Start": {
        "late_video_start": "late_video_start",
    },
    "Injury_Stoppage": {
        "in_chain": "in_chain",
    },
    "Interception": {
        "outcome": ("outcome", "name"),
    },
    "Miscontrol": {
        "aerial_won": "aerial_won",
    },
    "Player_Off": {
        "permanent": "permanent",
    },
    "Pressure": {
        "counterpress": "counterpress",
    },
    "Substitution": {
        "replacement": ("replacement", "name"),
        "outcome": ("outcome", "name"),
    }
}

# %%
# inserting events data. file took me ~2 minutes to execute

conn = psycopg2.connect(**conn_params)
cur = conn.cursor()

def get_value_from_json(event_json, keys):
    value = event_json
    for key in keys:
        try:
            if isinstance(value, dict):
                value = value[key]
            elif isinstance(key, int):  # Handling list indices
                value = value[key]
        except (KeyError, TypeError, IndexError):
            return None
    return value

def insert_event_data(event_json, match_id, event_type, cur, log_file):
    try:
        columns = ["match_id"]
        values = [match_id]

        # log_file.write(f"\nProcessing event: {event_json.get('id')}\n")
        # log_file.write(f"Event Type: {event_type}\n")

        # Add common event properties
        event_properties = events_dict.get("Event", {})
        for col, path in event_properties.items():
            value = get_value_from_json(event_json, path if isinstance(path, tuple) else [path])
            # log_file.write(f"Common Property: {col}, Extracted Value: {value}\n")
            if value is not None:
                columns.append(col)
                values.append(value)

        # Add event-specific properties
        event_specific_properties = events_dict.get(event_type, {})
        event_type_json = event_json.get(event_type.lower(), {})

        for col, path in event_specific_properties.items():
            if isinstance(path, tuple):
                # nested attributes are fetched from within the event-specific JSON
                value = get_value_from_json(event_type_json, path)
            else:
                json_key = path if isinstance(path, str) else path[1]
                value = event_type_json.get(json_key)

            # log_file.write(f"Event-specific Property: {col}, Extracted Value: {value}\n")
            if value is not None:
                columns.append(col)
                values.append(value)

        query = f"INSERT INTO {event_type} ({', '.join(columns)}) VALUES ({', '.join(['%s'] * len(values))})"
        cur.execute(query, values)
        conn.commit()
        # log_file.write(f"Successful Insert: {query} Values: {values}\n")

    except Exception as e:
        conn.rollback()
        # log_file.write(f"Error inserting event {event_json.get('id', 'Unknown')} for match {match_id}: {e}\n")

def process_events_folder(folder_path, cur, log_file_path):
    with open(log_file_path, 'a') as log_file:
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                if file.endswith('.json'):
                    match_id = int(file.split('.')[0])
                    with open(os.path.join(root, file), 'r') as f:
                        events = json.load(f)
                        for event_json in events:
                            event_type_name = get_value_from_json(event_json, ["type", "name"])
                            event_type_name = event_type_name.replace(' ', '_').replace('*', '')
                            if event_type_name == "Goal_Keeper":
                                event_type_name = "Goalkeeper"
                            if event_type_name in events_dict:
                                insert_event_data(event_json, match_id, event_type_name, cur, log_file)
                            # else:
                                # log_file.write(f"Unprocessed event type: {event_type_name}\n")
                                
folder_path = 'open-data/data/events'
log_file_path = 'logfile.txt'
process_events_folder(folder_path, cur, log_file_path)

conn.close()

# %%
# lineups data
conn = psycopg2.connect(**conn_params)
cur = conn.cursor()

def insert_lineup_data(file_path, match_id, cur):
    try:
        with open(file_path, 'r') as file:
            lineup_details = json.load(file)
        
        query = "INSERT INTO Lineups (match_id, lineup_details) VALUES (%s, %s)"
        values = (match_id, json.dumps(lineup_details))
        
        cur.execute(query, values)
        conn.commit()
        
    except Exception as e:
        conn.rollback()
        print(f"Error inserting lineup for match {match_id}: {e}")

def process_lineups_folder(folder_path, cur):
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.json'):
                match_id = int(file.split('.')[0])
                file_path = os.path.join(root, file)
                insert_lineup_data(file_path, match_id, cur)

folder_path = 'open-data/data/lineups'
process_lineups_folder(folder_path, cur)


conn.close()

# %%
# with the above script, all data should be loaded to the db
# dump command:
# pg_dump --file "/Users/saipaladugu/Desktop/dbexport.sql" --host "localhost" --port "5432" --username "postgres" --verbose --format=p "project_database"
cur.close()
